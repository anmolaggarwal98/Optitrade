# %%
import socket
import select

REMOTE_IP = "178.62.36.224"
UDP_ANY_IP = ""

USERNAME = "Team15"
PASSWORD = "KG4HgHEE"


# -------------------------------------
# EML code (EML is execution market link)
# -------------------------------------

EML_UDP_PORT_LOCAL = 8078
EML_UDP_PORT_REMOTE = 8001

eml_sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
eml_sock.bind((UDP_ANY_IP, EML_UDP_PORT_LOCAL))


# -------------------------------------
# IML code (IML is information market link)
# -------------------------------------

IML_UDP_PORT_LOCAL = 7078
IML_UDP_PORT_REMOTE = 7001
IML_INIT_MESSAGE = "TYPE=SUBSCRIPTION_REQUEST"

iml_sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
iml_sock.bind((UDP_ANY_IP, IML_UDP_PORT_LOCAL))


# -------------------------------------
# Auto trader
# -------------------------------------

def start_autotrader():
    subscribe()
    event_listener()


def subscribe():
    iml_sock.sendto(IML_INIT_MESSAGE.encode(), (REMOTE_IP, IML_UDP_PORT_REMOTE))


def event_listener():
    """
    Wait for messages from the exchange and
    call handle_message on each of them.
    """
    while True:
        ready_socks,_,_ = select.select([iml_sock, eml_sock], [], [])
        for socket in ready_socks:
            data, addr = socket.recvfrom(1024)
            message = data.decode('utf-8')
            handle_message(message)


def handle_message(message):
    comps = message.split("|")

    if len(comps) == 0:
        print(f"Invalid message received: {message}")
        return

    type = comps[0]

    if type == "TYPE=PRICE":

        feedcode = comps[1].split("=")[1]
        bid_price = float(comps[2].split("=")[1])
        bid_volume = int(comps[3].split("=")[1])
        ask_price = float(comps[4].split("=")[1])
        ask_volume = int(comps[5].split("=")[1])

        print(f"[PRICE] product: {feedcode} bid: {bid_volume}@{bid_price} ask: {ask_volume}@{ask_price}")

    if type == "TYPE=TRADE":

        feedcode = comps[1].split("=")[1]
        side = comps[2].split("=")[1]
        traded_price = float(comps[3].split("=")[1])
        traded_volume = int(comps[4].split("=")[1])

        print(f"[TRADE] product: {feedcode} side: {side} price: {traded_price} volume: {traded_volume}")

    if type == "TYPE=ORDER_ACK":

        if comps[1].split("=")[0] == "ERROR":
            error_message = comps[1].split("=")[1]
            print(f"Order was rejected because of error {error_message}.")
            return

        feedcode = comps[1].split("=")[1]
        traded_price = float(comps[2].split("=")[1])

        # This is only 0 if price is not there, and volume became 0 instead.
        # Possible cause: someone else got the trade instead of you.
        if traded_price == 0:
            print(f"Unable to get trade on: {feedcode}")
            return

        traded_volume = int(comps[3].split("=")[1])

        print(f"[ORDER_ACK] feedcode: {feedcode}, price: {traded_price}, volume: {traded_volume}")


def send_order(target_feedcode, action, target_price, volume):
    """
    Send an order to the exchange.
    :param target_feedcode: The feedcode, either "SP-FUTURE" or "ESX-FUTURE"
    :param action: "BUY" or "SELL"
    :param target_price: Price you want to trade at
    :param volume: Volume you want to trade at. Please start with 10 and go from there. Don't go crazy!
    :return:
    Example:
    If you want to buy  100 SP-FUTURES at a price of 3000:
    - send_order("SP-FUTURE", "BUY", 3000, 100)
    """
    order_message = f"TYPE=ORDER|USERNAME={USERNAME}|PASSWORD={PASSWORD}|FEEDCODE={target_feedcode}|ACTION={action}|PRICE={target_price}|VOLUME={volume}"
    print(f"[SENDING ORDER] {order_message}")
    eml_sock.sendto(order_message.encode(), (REMOTE_IP, EML_UDP_PORT_REMOTE))
    


# -------------------------------------
# Main
# -------------------------------------

if __name__ == "__main__":
    #start_autotrader()
# Out:
# [TRADE] product: SP-FUTURE side: ASK price: 3026.25 volume: 358
# [PRICE] product: ESX-FUTURE bid: 1289@3191.25 ask: 2755@3191.5
# [TRADE] product: ESX-FUTURE side: ASK price: 3191.5 volume: 2034
# [PRICE] product: SP-FUTURE bid: 484@3027.25 ask: 1915@3027.5
# [TRADE] product: SP-FUTURE side: BID price: 3027.25 volume: 389
# [PRICE] product: ESX-FUTURE bid: 1437@3191.0 ask: 2607@3191.25
# [TRADE] product: ESX-FUTURE side: BID price: 3191.0 volume: 610
# [PRICE] product: SP-FUTURE bid: 738@3027.0 ask: 1661@3027.25
# [TRADE] product: ESX-FUTURE side: BID price: 3191.0 volume: 402
# [PRICE] product: SP-FUTURE bid: 2055@3026.75 ask: 344@3027.0
# [TRADE] product: SP-FUTURE side: ASK price: 3027.0 volume: 21
# [PRICE] product: ESX-FUTURE bid: 1482@3191.0 ask: 2562@3191.25
# [TRADE] product: ESX-FUTURE side: BID price: 3191.0 volume: 177
# [PRICE] product: SP-FUTURE bid: 1763@3026.75 ask: 636@3027.0
# [TRADE] product: SP-FUTURE side: ASK price: 3027.0 volume: 291
# [PRICE] product: ESX-FUTURE bid: 3696@3191.0 ask: 348@3191.25
# [TRADE] product: ESX-FUTURE side: ASK price: 3191.25 volume: 129
# [PRICE] product: SP-FUTURE bid: 2023@3026.75 ask: 376@3027.0
# [TRADE] product: ESX-FUTURE side: BID price: 3191.0 volume: 1115
# [PRICE] product: SP-FUTURE bid: 1194@3026.75 ask: 1205@3027.0
# [TRADE] product: ESX-FUTURE side: ASK price: 3191.25 volume: 107
# [PRICE] product: SP-FUTURE bid: 1389@3026.75 ask: 1010@3027.0
# [TRADE] product: SP-FUTURE side: ASK price: 3027.0 volume: 595
# [PRICE] product: ESX-FUTURE bid: 1565@3191.5 ask: 2479@3191.75
# [TRADE] product: ESX-FUTURE side: ASK price: 3191.75 volume: 1587
# [PRICE] product: SP-FUTURE bid: 1747@3027.5 ask: 652@3027.75
# [TRADE] product: ESX-FUTURE side: ASK price: 3191.75 volume: 1035
# [PRICE] product: SP-FUTURE bid: 198@3028.0 ask: 2201@3028.25
# [TRADE] product: SP-FUTURE side: BID price: 3028.0 volume: 31
# [PRICE] product: ESX-FUTURE bid: 1480@3191.5 ask: 2564@3191.75
# [TRADE] product: SP-FUTURE side: BID price: 3028.0 volume: 4
# [PRICE] product: ESX-FUTURE bid: 1477@3191.5 ask: 2567@3191.75
# [TRADE] product: SP-FUTURE side: BID price: 3028.0 volume: 1
# [PRICE] product: ESX-FUTURE bid: 1477@3191.5 ask: 2567@3191.75
# [PRICE] product: SP-FUTURE bid: 567@3028.0 ask: 1832@3028.25
# [TRADE] product: ESX-FUTURE side: ASK price: 3186.0 volume: 80
# [PRICE] product: SP-FUTURE bid: 699@3028.0 ask: 1700@3028.25
# [TRADE] product: SP-FUTURE side: BID price: 3028.0 volume: 134
# [PRICE] product: ESX-FUTURE bid: 3253@3185.75 ask: 791@3186.0
# [TRADE] product: ESX-FUTURE side: BID price: 3185.75 volume: 42
# [PRICE] product: SP-FUTURE bid: 689@3028.0 ask: 1710@3028.25
# [TRADE] product: ESX-FUTURE side: ASK price: 3186.0 volume: 328
# [PRICE] product: SP-FUTURE bid: 1665@3028.0 ask: 734@3028.25
# [TRADE] product: SP-FUTURE side: ASK price: 3028.25 volume: 120
# [PRICE] product: ESX-FUTURE bid: 3765@3185.75 ask: 279@3186.0
# [TRADE] product: ESX-FUTURE side: BID price: 3185.75 volume: 59
# [PRICE] product: SP-FUTURE bid: 1660@3028.0 ask: 739@3028.25
# [TRADE] product: ESX-FUTURE side: ASK price: 3186.0 volume: 278
# [PRICE] product: SP-FUTURE bid: 131@3028.25 ask: 2268@3028.5
# [TRADE] product: SP-FUTURE side: ASK price: 3028.5 volume: 223
# [PRICE] product: ESX-FUTURE bid: 3872@3185.75 ask: 172@3186.0
# [TRADE] product: SP-FUTURE side: ASK price: 3028.5 volume: 2206
# [PRICE] product: ESX-FUTURE bid: 921@3188.25 ask: 3123@3188.5
# [TRADE] product: ESX-FUTURE side: BID price: 3188.25 volume: 294
# [PRICE] product: SP-FUTURE bid: 1743@3028.0 ask: 656@3028.25
# [TRADE] product: SP-FUTURE side: BID price: 3028.0 volume: 598
# [PRICE] product: ESX-FUTURE bid: 2126@3188.0 ask: 1918@3188.25
# [TRADE] product: SP-FUTURE side: BID price: 3028.0 volume: 1742
# [PRICE] product: ESX-FUTURE bid: 3868@3185.5 ask: 176@3185.75
# [TRADE] product: ESX-FUTURE side: BID price: 3185.5 volume: 1509
# [PRICE] product: SP-FUTURE bid: 980@3028.0 ask: 1419@3028.25
# [TRADE] product: SP-FUTURE side: ASK price: 3028.25 volume: 186
# [PRICE] product: ESX-FUTURE bid: 423@3185.75 ask: 3621@3186.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1e3b78d0382d> in <module>
#     129
#     130 if __name__ == "__main__":
# --> 131     start_autotrader()
#
# <ipython-input-1-1e3b78d0382d> in start_autotrader()
#      38 def start_autotrader():
#      39     subscribe()
# ---> 40     event_listener()
#      41
#      42
#
# <ipython-input-1-1e3b78d0382d> in event_listener()
#      51     """
#      52     while True:
# ---> 53         ready_socks,_,_ = select.select([iml_sock, eml_sock], [], [])
#      54         for socket in ready_socks:
#      55             data, addr = socket.recvfrom(1024)
#
# KeyboardInterrupt:

# %%
send_order("SP-FUTURE", "BUY", 3000, 100)
# Out:
# [SENDING ORDER] TYPE=ORDER|USERNAME=Team15|PASSWORD=KG4HgHEE|FEEDCODE=SP-FUTURE|ACTION=BUY|PRICE=3000|VOLUME=100
